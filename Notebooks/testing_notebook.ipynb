# %% [markdown]
# # Testing Notebook

# %%
# %matplotlib inline 

import os 
import sys
import EEPS.initialization as initialization
import EEPS.initialization_detail as initialization_detail
import EEPS.environment as env
import EEPS.agent as agn
import EEPS.interaction as intrc
import pdb
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(20.0, 10.0))

Path = ''
sys.path.insert(0, Path)

environment_detail = initialization_detail.environment_details()
environment_parameter, agent_parameter = initialization.config()


# Give the file_name to just plot a previousely saved simulation
file_name = None

if file_name == None:
    agent = agn.Agent(agent_parameter)
    environment = env.Environment(environment_parameter)
    interaction = intrc.Interaction(agent, environment, agent_parameter,
                                                        environment_parameter, 100, None, None)
    interaction.run_save()
    file_name = interaction.file_name
    print(file_name)

results = intrc.Plot_results(file_name)
results.showResults()
results.print_setting()
# Out:
# 0
# ['A1', 'B1', 'B3', 'B2', 'A2', 'A3']
# {'A1': 'A', 'B1': 'B', 'B3': 'B', 'B2': 'B', 'A2': 'A', 'A3': 'A'}
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[1], line 29
#      26 environment = env.Environment(environment_parameter)
#      27 interaction = intrc.Interaction(agent, environment, agent_parameter,
#      28                                                     environment_parameter, 100, None, None)
# ---> 29 interaction.run_save()
#      30 file_name = interaction.file_name
#      31 print(file_name)
#
# File c:\Users\gx19928\EEPS-Visualizations\interaction.py:221, in Interaction.run_save(self)
#     214 def run_save(self): # Ok!
#     216     """
#     217     This is to save the results into pickle files for plotting
#     218     and further calls.
#     219     """
# --> 221     results = self.experiment_results()
#     222     show, result = self.plot_data(results)
#     224     Simulation_data = {}
#
# File c:\Users\gx19928\EEPS-Visualizations\interaction.py:92, in Interaction.experiment_results(self)
#      90 self.environment = copy.deepcopy(environment)
#      91 self.agent = copy.deepcopy(agent)
# ---> 92 self.run_experiment()
#      94 if i_trial == 0:
#      95     avg_time_training = self.environment.num_iteration_training.copy()
#
# File c:\Users\gx19928\EEPS-Visualizations\interaction.py:72, in Interaction.run_experiment(self)
#      69 self.agent.training_update_network(percept, action_set_t,
#      70                                    action, reward)
#      71 if num_steps % self.vis_step == 0:
# ---> 72     self.agent.visualize_memory(self.canvas, self.figure)
#
# File c:\Users\gx19928\EEPS-Visualizations\agent.py:324, in Agent.visualize_memory(self, canvas, figure)
#     322 nx.draw_networkx_labels(self.clip_space, pos)
#     323 nx.draw_networkx_edges(self.clip_space, pos, edge_color='r', arrows=True)
# --> 324 nx.draw(self.clip_space, pos, memory_plot)
#     326 if canvas is not None:
#     327     canvas.draw_idle()
#
# UnboundLocalError: cannot access local variable 'memory_plot' where it is not associated with a value
